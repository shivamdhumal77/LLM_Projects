# %%
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from langchain.llms import Ollama
from langchain.text_splitter import CharacterTextSplitter

# Initialize the Ollama model
llm = Ollama(model="llama3.2")  # Replace with your Ollama model name or path

# Function to split large text into manageable chunks
def split_text_into_chunks(input_text, chunk_size=1000, overlap=50):
    splitter = CharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=overlap)
    return splitter.split_text(input_text)

# Function to generate questions from a chunk
def generate_questions_from_chunk(chunk, num_questions):
    prompt = (
        f"Generate {num_questions} unique, diverse, and thought-provoking questions based on the following text: \n\n"
        f"{chunk}"
    )
    response = llm(prompt)
    
    # Filter out non-question content (such as category headers or irrelevant text)
    questions = [q.strip() for q in response.strip().split("\n") if "?" in q]
    return questions

# Main function to handle input and generate a desired number of questions
def generate_questions(input_text, total_questions=100):
    # Dynamically adjust chunk size based on input text length
    text_length = len(input_text)
    chunk_size = min(1000, max(500, text_length // 5))  # Adjust chunk size depending on the input length
    overlap = 50
    chunks = split_text_into_chunks(input_text, chunk_size, overlap)

    # Questions to generate per chunk
    questions_per_chunk = max(1, total_questions // len(chunks))
    all_questions = []

    # Process each chunk
    for chunk in chunks:
        try:
            # Generate questions for the current chunk
            questions = generate_questions_from_chunk(chunk, questions_per_chunk)
            all_questions.extend(questions)
        except Exception as e:
            print(f"Error generating questions for chunk: {e}")

    # Deduplicate and refine questions
    unique_questions = list(set([q.strip() for q in all_questions if q.strip()]))
    
    # Adjust to the required number of questions and number them sequentially
    numbered_questions = [f"{i + 1}. {question}" for i, question in enumerate(unique_questions[:total_questions])]

    return numbered_questions

# Get user input for the text and number of questions
input_text = input("Please enter the text you want to generate questions from: ")
total_questions = int(input("How many questions would you like to generate? "))

# Generate questions
questions = generate_questions(input_text, total_questions)

# Print the questions
for q in questions:
    print(q)
# Out:
# 1. 66. Can AI improve social connections and relationships?
# 2. 83. Are there any potential risks associated with relying on AI for complex tasks or decision-making?
# 3. 79. How can we ensure that AI development aligns with human values and ethics?
# 4. 70. What are the implications of widespread AI adoption for human relationships?
# 5. 93. Can AI help improve global governance, policy-making, and decision-making?
# 6. 65. What role will humans play in driving AI-powered innovation?
# 7. 27. Can AI improve working conditions or create new jobs for humans?
# 8. 52. Can AI help address issues of poverty, inequality, and social injustice?
# 9. 81. What are some common challenges associated with developing and deploying AI systems?
# 10. 31. What will be the most significant impact of AI on society over the next decade?
# 11. 87. Are there any potential risks associated with relying on AI for surveillance and monitoring?
# 12. 44. How can we ensure that AI is used to support teacher development and professional growth?
# 13. 59. Are there any potential risks associated with relying on AI for workforce optimization?
# 14. 60. What are the benefits and drawbacks of using AI to augment human skills?
# 15. 57. Can AI help create new job opportunities or enhance existing ones?
# 16. 30. Can AI help address issues of bias and fairness in various industries?
# 17. 23. How do AI recommendation systems enhance the viewer experience?
# 18. 71. How can governments regulate AI development to ensure public safety?
# 19. 8. What are the potential risks of relying on AI for medical diagnosis and treatment?
# 20. 94. How can we ensure that AI development prioritizes global cooperation and understanding?
# 21. 9. How can we balance the benefits of AI-driven medicine with human intuition?
# 22. 61. What are some new business models or revenue streams emerging due to AI adoption?
# 23. 64. How can we promote innovation and entrepreneurship in the face of AI-driven disruption?
# 24. 55. What are the implications of AI adoption for global governance and policy-making?
# 25. 6. How effective are AI-powered diagnostic tools in early disease detection?
# 26. 21. What role does AI play in creating realistic visual effects in film and gaming?
# 27. 11. How do robo-advisors use AI to provide personalized investment advice?
# 28. 15. How can we ensure that AI is used to promote economic growth rather than inequality?
# 29. 29. Are there any potential risks associated with relying on AI for decision-making?
# 30. 98. How can we ensure that AI development prioritizes sustainability, resilience, and adaptability?
# 31. 3. Can AI truly replicate human intelligence, or are there limitations?
# 32. 1. How is AI changing the way we live our daily lives?
# 33. 24. Are there any potential risks associated with relying on AI-generated content?
# 34. 99. Are there any potential risks associated with relying on AI for long-term decision-making or planning?
# 35. 75. How can we balance individual rights and freedoms with the need for AI-powered security measures?
# 36. 2. What are the benefits and drawbacks of relying on AI in various industries?
# 37. 50. What are the implications of widespread AI adoption for national security?
# 38. 42. Can AI help create more effective learning materials and curricula?
# 39. 25. Can AI help personalize experiences in various forms of entertainment?
# 40. 76. Can AI truly be considered "intelligent" or is it just complex?
# 41. 100. What are the implications of widespread AI adoption for our understanding of human existence and the future of humanity?
# 42. 53. Are there any potential risks associated with relying on AI for international relations?
# 43. 43. Are there any potential risks associated with relying on AI for teacher training?
# 44. 12. What are the advantages of using AI-powered algorithms for market analysis and risk assessment?
# 45. 32. How can we prepare for a future where AI is an integral part of our lives?
# 46. 45. What are the benefits and drawbacks of AI-driven educational tools?
# 47. 68. Are there any potential risks associated with relying on AI for emotional support or companionship?
# 48. 17. Can AI improve traffic congestion by optimizing vehicle routing and schedules?
# 49. 56. What job skills will be most relevant in an AI-driven economy?
# 50. 41. What role will AI play in the future of education, such as personalized learning?
# 51. 33. Are there any potential risks or challenges associated with widespread AI adoption?
# 52. 63. Are there any potential risks associated with relying on AI for venture capital investment?
# 53. 22. Can AI-generated content provide new creative opportunities for artists?
# 54. 97. Can AI help solve complex, long-term problems related to climate change, poverty, and inequality?
# 55. 58. How can we prepare workers for a future where AI is increasingly prevalent?
# 56. 72. Are there any potential risks associated with relying on AI for decision-making in governance?
# 57. 4. How can we ensure that AI is developed and deployed in an ethical manner?
# 58. 86. Can AI help promote social justice and equality?
# 59. 47. Are there any potential risks associated with relying on AI for surveillance and monitoring?
# 60. 51. What role will AI play in global economic development and growth?
# 61. 67. How can we ensure that AI is developed to promote inclusivity and diversity?
# 62. 39. Are there any potential risks associated with relying on AI for disaster response and recovery?
# 63. 85. What are some common limitations of current AI systems, such as natural language processing?
# 64. 80. What are the implications of widespread AI adoption for our understanding of human existence?
# 65. 89. Can AI help improve decision-making in areas related to healthcare, finance, and education?
# 66. 19. How can we balance the need for autonomous vehicles with human safety concerns?
# 67. 7. Can AI improve patient outcomes by identifying patterns in medical data?
# 68. 74. What role will humans play in shaping the future of regulatory frameworks?
# 69. 48. How can we balance individual privacy with the need for AI-powered security measures?
# 70. 28. How can we ensure that AI is developed with social responsibility in mind?
# 71. 38. Can AI help optimize logistics and transportation networks?
# 72. 62. Can AI help entrepreneurs identify new market opportunities?
# 73. 88. How can we ensure that AI development prioritizes human rights and dignity?
# 74. 14. Are there any potential risks associated with relying on AI for financial decision-making?
# 75. 92. Are there any potential risks associated with relying on AI for global communication or diplomacy?
# 76. 26. What are the consequences of job displacement caused by AI adoption?
# 77. 46. Can AI help improve cybersecurity measures in various industries?
# 78. 69. Can AI help address issues of loneliness, isolation, and mental health?
# 79. 84. How can we ensure that AI development prioritizes transparency, accountability, and explainability?
# 80. 18. Are there any potential risks associated with relying on AI in vehicle design and manufacturing?
# 81. 36. How can AI improve supply chain management in various industries?
# 82. 13. Can AI help detect cyber threats in real-time, reducing financial losses?
# 83. 16. What are the benefits of self-driving cars for transportation efficiency and safety?
# 84. 95. What are some common challenges associated with developing international standards and regulations for AI?
# 85. 78. Can AI help resolve complex philosophical debates, such as the nature of consciousness?
# 86. 91. What role will international collaboration play in shaping the future of AI development?
# 87. 96. What will be the most significant long-term impact of AI on society over the next few decades?
# 88. 10. Are there any new treatments or medications being developed solely through AI-driven research?
# 89. 73. Can AI help improve policy-making by analyzing vast amounts of data?
# 90. 77. Are there any potential risks associated with relying on AI for moral decision-making?
# 91. 82. Can AI help address issues related to data quality, bias, and accuracy?
# 92. 5. What role should humans play alongside AI in driving progress?
# 93. 20. Will AI-powered vehicles revolutionize urban planning and city development?
# 94. 34. Can AI help solve complex global problems like climate change and poverty?
# 95. 35. What role will humans play in shaping the future of AI development?
# 96. 49. Can AI help detect cyber threats and prevent data breaches?
# 97. 90. What are the implications of widespread AI adoption for our understanding of fairness and bias?
# 98. 40. How can AI improve public services, such as education and healthcare?
# 99. 54. How can we ensure that AI is developed and deployed globally to promote peace and stability?
# 100. 37. What are the benefits of using AI in agriculture for precision farming and crop yields?
